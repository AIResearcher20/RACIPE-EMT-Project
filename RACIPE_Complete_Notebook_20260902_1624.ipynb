# %% [markdown]
# # RACIPE Project: EMT Modeling and Analysis\n\n**Date:** 2026-09-02 16:24

# %% [markdown]
# ## 1. Setup and Imports

# %%
import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns

# %% [markdown]
# ## 2. Tian ODE Model

# %% [markdown]
# ## 3. RACIPE Analysis

# %% [markdown]
# ## 4. GSE69667 Data Analysis

# %% [markdown]
# ## 5. Sensitivity and Perturbation

# %% [markdown]
# ## 6. Validation and Statistics

# %% [markdown]
# ## 7. Conclusions

# %% [markdown]
# ### References\n- Tian et al. (2013)\n- Huang et al. (2017)\n- GSE69667 (NCBI GEO)
