# %% [markdown]
# # RACIPE Project - EMT Modeling\n\n## Complete Analysis\n\nThis notebook contains all analyses for the RACIPE project:\n- Tian ODE model validation\n- RACIPE (10,000 models)\n- GSE69667 data analysis\n- Sensitivity analysis\n- Perturbation ranking\n- Replicate validation\n- Statistical tests\n\n**Date:** 2026-09-02\n**Project:** EMT Modeling and Analysis\n
