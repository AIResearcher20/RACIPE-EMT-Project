# %% [markdown]
# # 🧬 RACIPE Project: EMT Modeling and Analysis\n\n**Date:** 2026-09-02 16:53\n\n## 📊 Summary of Results\n\n- **RACIPE models:** 10000\n- **EMT Score range:** 0.013 - 1.000\n- **State distribution:** E: 21.3%, H: 38.5%, M: 40.2%\n- **GSE69667 range:** 0.717 - 0.997\n\n## 📈 Key Figures\n\n![Summary](figure_final_summary.png)\n\n## 🎯 Conclusion\n\nRACIPE successfully captures the full spectrum of EMT phenotypes.\nGSE69667 data validates the model predictions.\nE-cadherin and N-cadherin are the most influential determinants of EMT.\n\n---\n**Project Complete!** 🎉
